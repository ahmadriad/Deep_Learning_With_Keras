# %%
pip install utils

# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, activation
from tensorflow import random
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import matplotlib
# %matplotlib inline
import matplotlib.patches as mpatches

# %%
np.random.seed(1)
random.set_seed(1)

# %%
x= pd.read_csv("https://raw.githubusercontent.com/PacktWorkshops/The-Deep-Learning-with-Keras-Workshop/master/Chapter03/data/outlier_feats.csv")
y=pd.read_csv("https://raw.githubusercontent.com/PacktWorkshops/The-Deep-Learning-with-Keras-Workshop/master/Chapter03/data/outlier_target.csv")

# %%
matplotlib.rcParams['figure.figsize']=(10.0,8.0)
class_1 = plt.scatter(x.loc[y['Class']==0,'feature1'],x.loc[y['Class']==0,'feature2'],c="red",s=40)
class_2 = plt.scatter(x.loc[y['Class']==1,'feature1'],x.loc[y['Class']==1,'feature2'],c="blue",s=40)
plt.legend((class_1,class_2),("fail","pass"))
plt.xlabel('feature1')
plt.ylabel('feature2')
# Out:
# Text(0, 0.5, 'feature2')

# %%
model = Sequential()
model.add(Dense(1,input_dim = 2,activation="sigmoid"))
model.compile(loss="binary_crossentropy",metrics="accuracy",optimizer="sgd")
model.fit(x,y,epochs=100,batch_size=5,verbose=1,validation_split=.2,shuffle=False)
# Out:
# Epoch 1/100
# 538/538 [==============================] - 1s 2ms/step - loss: 0.5435 - accuracy: 0.8377 - val_loss: 0.4244 - val_accuracy: 0.9167
# Epoch 2/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3739 - accuracy: 0.9032 - val_loss: 0.3697 - val_accuracy: 0.8884
# Epoch 3/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3462 - accuracy: 0.8951 - val_loss: 0.3588 - val_accuracy: 0.8854
# Epoch 4/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3397 - accuracy: 0.8951 - val_loss: 0.3560 - val_accuracy: 0.8854
# Epoch 5/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3378 - accuracy: 0.8951 - val_loss: 0.3551 - val_accuracy: 0.8854
# Epoch 6/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3371 - accuracy: 0.8951 - val_loss: 0.3547 - val_accuracy: 0.8854
# Epoch 7/100
# ...

# %%
model_1 = Sequential()
model_1.add(Dense(3,input_dim=2,activation="sigmoid"))
model_1.add(Dense(1,activation="sigmoid"))
model_1.compile(optimizer='sgd',metrics="accuracy",loss="binary_crossentropy")
model_1.fit(x,y,epochs=100,batch_size=5,verbose=1,validation_split=.2,shuffle=False)
# Out:
# Epoch 1/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.4556 - accuracy: 0.8515 - val_loss: 0.3667 - val_accuracy: 0.8854
# Epoch 2/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3423 - accuracy: 0.8951 - val_loss: 0.3504 - val_accuracy: 0.8854
# Epoch 3/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3342 - accuracy: 0.8951 - val_loss: 0.3481 - val_accuracy: 0.8854
# Epoch 4/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3323 - accuracy: 0.8951 - val_loss: 0.3471 - val_accuracy: 0.8854
# Epoch 5/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3313 - accuracy: 0.8951 - val_loss: 0.3462 - val_accuracy: 0.8854
# Epoch 6/100
# 538/538 [==============================] - 1s 1ms/step - loss: 0.3304 - accuracy: 0.8951 - val_loss: 0.3451 - val_accuracy: 0.8854
# Epoch 7/100
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, activation
import matplotlib.pyplot as plt

# %%
x = pd.read_csv("https://raw.githubusercontent.com/PacktWorkshops/The-Deep-Learning-with-Keras-Workshop/master/Chapter03/data/HCV_feats.csv")
y = pd.read_csv("https://raw.githubusercontent.com/PacktWorkshops/The-Deep-Learning-with-Keras-Workshop/master/Chapter03/data/HCV_target.csv")

# %%
print(f"Number of features: {x.shape[1]}")
print(f"Number of examples: {x.shape[0]}")
print(f"Number of features: {np.unique(y)}")
# Out:
# Number of features: 28
# Number of examples: 1385
# Number of features: [0 1]

# %%
sc= StandardScaler()
x = pd.DataFrame(sc.fit_transform(x))

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=43)
print(x_tarin.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1108, 28) (277, 28) (1108, 1) (277, 1)

# %%
model = Sequential()
model.add(Dense(3,input_dim=x_train.shape[1],activation='tanh'))
model.add(Dense(1,activation="sigmoid"))
model.compile(loss="binary_crossentropy",optimizer="sgd",metrics="accuracy")
history=model.fit(x_train,y_train,epochs=100,batch_size=20,validation_split=.1,shuffle=False)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 1s 4ms/step - loss: 0.8471 - accuracy: 0.4875 - val_loss: 0.8089 - val_accuracy: 0.5495
# Epoch 2/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.8209 - accuracy: 0.4905 - val_loss: 0.7902 - val_accuracy: 0.5405
# Epoch 3/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7996 - accuracy: 0.4925 - val_loss: 0.7749 - val_accuracy: 0.5405
# Epoch 4/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7822 - accuracy: 0.4965 - val_loss: 0.7624 - val_accuracy: 0.5405
# Epoch 5/100
# 50/50 [==============================] - 0s 1ms/step - loss: 0.7680 - accuracy: 0.4995 - val_loss: 0.7521 - val_accuracy: 0.5405
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.7563 - accuracy: 0.4995 - val_loss: 0.7436 - val_accuracy: 0.5405
# Epoch 7/100
# ...

# %%
# %matplotlib inline
plt.plot(history.history['loss'],label="trainin")
plt.plot(history.history['val_loss'],label="validation")
plt.legend()
plt.xlim(0,100)
# Out:
# (0.0, 100.0)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
loss, accu = model.evaluate(x_test,y_test)
print(loss,accu)
# Out:
# 9/9 [==============================] - 0s 1ms/step - loss: 0.6951 - accuracy: 0.5054
# 0.695103108882904 0.505415141582489

# %%
model.add(Dense(4,input_dim=x_train.shape[1],activation='tanh'))
model.add(Dense(2,activation='tanh'))
model.add(Dense(1,activation="sigmoid"))
model.compile(loss="binary_crossentropy",optimizer="sgd",metrics="accuracy")
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 3)                 87
#
#  dense_11 (Dense)            (None, 1)                 4
#
#  dense_12 (Dense)            (None, 4)                 8
#
#  dense_13 (Dense)            (None, 2)                 10
#
#  dense_14 (Dense)            (None, 1)                 3
#
# ...
# Total params: 112
# Trainable params: 112
# Non-trainable params: 0
# _________________________________________________________________

# %%
History=model.fit(x_train,y_train,epochs=100,batch_size=20,validation_split=.1,shuffle=False)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 0s 3ms/step - loss: 0.6922 - accuracy: 0.5176 - val_loss: 0.6908 - val_accuracy: 0.5405
# Epoch 2/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5176 - val_loss: 0.6908 - val_accuracy: 0.5405
# Epoch 3/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5176 - val_loss: 0.6908 - val_accuracy: 0.5405
# Epoch 4/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5176 - val_loss: 0.6908 - val_accuracy: 0.5405
# Epoch 5/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5176 - val_loss: 0.6908 - val_accuracy: 0.5405
# Epoch 6/100
# 50/50 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5176 - val_loss: 0.6908 - val_accuracy: 0.5405
# Epoch 7/100
# ...

# %%
loss,accu=model.evaluate(x_test,y_test)
print(loss,accu)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 0.6930 - accuracy: 0.5090
# 0.6929880380630493 0.5090252757072449

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
